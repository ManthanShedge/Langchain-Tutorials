# %% [markdown]
# ### Models Integration with OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY']=os.getenv('OPENAI_API_KEY')
os.environ['GROQ_API_KEY']=os.getenv('GROQ_API_KEY')
os.environ['GOOGLE_API_KEY']=os.getenv('GOOGLE_API_KEY')

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("gpt-4.1")
model

# %%
## invoke the model
response = model.invoke("Hello, how are you?")
response

# %%
###ChatOpenAI

from langchain_openai import ChatOpenAI

model=ChatOpenAI(model="gpt-4.1")
response = model.invoke("Hello, how are you?")
response

# %%
response.content

# %% [markdown]
# ### Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ['GOOGLE_API_KEY']=os.getenv('GOOGLE_API_KEY')

model=init_chat_model("google_genai:gemini-2.5-flash-lite")
response=model.invoke("Hello, how are you?")
response.content

# %%
###ChatGoogleGenerativeAI

import os
from langchain_google_genai import ChatGoogleGenerativeAI

model=ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Hello, how are you?")
response

# %% [markdown]
# ### GROQ Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

os.environ['GROQ_API_KEY']=os.getenv('GROQ_API_KEY')

model=init_chat_model("groq:qwen/qwen3-32b")
response=model.invoke("Hello, how are you?")
response.content

# %%
###ChatGroq

import os
from langchain_groq import ChatGroq

model=ChatGroq(model="qwen/qwen3-32b")
response = model.invoke("Hello, how are you?")
response

# %% [markdown]
# ### Streaming and Batch

# %% [markdown]
# ### Streaming

# %% [markdown]
# ##### Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly enhances user experience, particularly for longer responses. Calling stream() returns an iterator that yields output chunks as they are generated. You can use a loop to process each chunk in real time:

# %%
for chunk in model.stream("Why is the sky blue?"):
    print(chunk.text, end="|", flush=True)

# %% [markdown]
# ### Batch

# %% [markdown]
# ##### Batching a collection of independent requests to a model can signicantly improve performance and reduce costs, as the processing can be done in parallel.

# %%
responses = model.batch(["Why is the sky blue?","What is meaning of life?","How can I make money?"])
for response in responses:
    print(response)

# %%
model.batch(["Why is the sky blue?",
"What is meaning of life?",
"How can I make money?"], config={"max_concurrency": 5})
